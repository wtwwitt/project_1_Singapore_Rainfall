# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# > rainfall-monthly-number-of-rain-days.csv -
# > Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# >
# > rainfall-monthly-total.csv -
# > Monthly total rain recorded in mm(millimeters) from 1982 to 2022
# >
# > Relative Humidity -
# > Monthly average relative humidity (percentage) from 1982 to 2023
# >
# > Monthly mean sunshine hours -
# > Monthly average sunshine hours from 1982 to 2023
# >
# > Surface Air Temperature -
# > Monthly average surface temperature in degree celsius from 1982 to 2023

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.

# %% [markdown]
# Rainfall affects daily activities of Singapore population, hence it is worth analysing rainfall data to identify trends

# %% [markdown]
# > **Problem Statement:**
# >
# > ~~For food centers in Singapore, some of them uses the outdoor area for events such as Satay Street which is heavily impact by the weather condition. This project aims to analyze the monthly weather patterns over the past years to provide them a better plan for managing their resources.~~
# >
# > When traveling to Singapore, it seems that visitor will likely to encounter rain whatever the month is. The analysis in this project should be able to help those who plan to travel to Singapore to get better preparation and adaptation on their plan for the good traveling experience.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# > * Relationship between wet bulb temperature and surface temperture, when the surface temperature and the wet bulb temperature are close together, it indicates that the air is close to becoming saturated. Therefore, the difference between both value is directly related to humidity.
# >
# >   However, this information cannot be used in the project due to limitation on source data. Moreover, to predict the rain chance from these values, it still requires a lot more parameters which will be too complex to do so.
# >
# > * Average flight cost from Bangkok to Singapore and average hotel price on each month from Google Flight
# >
# > * Singapore events in each season that affect the number of tourist

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
import numpy as np

def mean_calc(list):
    return np.mean(list)

# %%
mean_calc([3, 5, 6, 12, 4])
# Out:
# 6.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_calc(list):
    return ((1/len(list)) * sum([(x - mean_calc(list))**2 for x in list]))**0.5

# %%
std_calc([3, 5, 6, 12, 4])
# Out:
# 3.1622776601683795

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Load data
rain_days = pd.read_csv('../data/rainfall-monthly-number-of-rain-days.csv')
rain_amount = pd.read_csv('../data/rainfall-monthly-total.csv')
humid = pd.read_csv('../data/RelativeHumidityMonthlyMean.csv')
sunshine_hours = pd.read_csv('../data/SunshineDurationMonthlyMeanDailyDuration.csv')
surface_temp = pd.read_csv('../data/SurfaceAirTemperatureMonthlyMean.csv')
# wbt = pd.read_csv('../data/WetBulbTemperatureHourly.csv')
# surface_temp = pd.read_csv('../data/SurfaceAirTemperatureMonthlyMeanDailyMinimum.csv')

# %%
# Display raw data
rain_days.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
# Display raw data
rain_amount.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
# Display raw data
humid.head()
# Out:
#      month  mean_rh
# 0  1982-01     81.2
# 1  1982-02     79.5
# 2  1982-03     82.3
# 3  1982-04     85.9
# 4  1982-05     83.2

# %%
# Display raw data
sunshine_hours.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
# wbt.head()

# %%
# Display raw data
surface_temp.head()
# Out:
#      month  mean_temp
# 0  1982-01       25.9
# 1  1982-02       27.1
# 2  1982-03       27.2
# 3  1982-04       27.0
# 4  1982-05       28.0

# %%
# Calculate hourly different of wet bulb temperature and change wbt_date to datetime
# wbt['hourly_diff'] = wbt['wet_bulb_temperature'].diff()
# wbt['wbt_date'] = pd.to_datetime(wbt['wbt_date'])
# wbt.info()
# wbt.head()

# %%
# Calculate maximum and minimum hourly diff of wbt per day, merge into new df
# temp_df_1 = wbt.groupby('wbt_date')[['hourly_diff']].min().rename(columns={'hourly_diff': 'wbt_lowest_hourly_diff'}).reset_index()
# temp_df_2 = wbt.groupby('wbt_date')[['hourly_diff']].max().rename(columns={'hourly_diff': 'wbt_highest_hourly_diff'}).reset_index()
# wbt_daily = temp_df_1.merge(temp_df_2, on='wbt_date')
# del temp_df_1
# del temp_df_2
# wbt_daily.head()

# %%
# Create new True/False column to indicate if highest/lowest daily wbt diff is higher/less than average
# avg_lowest_hourly_diff_wbt = wbt.groupby('wbt_date')['hourly_diff'].min().mean()
# avg_highest_hourly_diff_wbt = wbt.groupby('wbt_date')['hourly_diff'].max().mean()
# wbt_daily['lowest_wbt_diff_below_avg'] = wbt_daily['wbt_lowest_hourly_diff'].apply(lambda x: x < -1.1)
# wbt_daily['highest_wbt_diff_above_avg'] = wbt_daily['wbt_highest_hourly_diff'].apply(lambda x: x > 1.1)
# wbt_daily.head()

# %%
# Count newly created True/False column for number of days that lowest/highest wbt diff higher/lower than average 
# temp_df_1 = wbt_daily.groupby([wbt_daily['wbt_date'].dt.year, wbt_daily['wbt_date'].dt.month]).agg({'lowest_wbt_diff_below_avg': 'sum', 'wbt_date': 'first'})
# temp_df_2 = wbt_daily.groupby([wbt_daily['wbt_date'].dt.year, wbt_daily['wbt_date'].dt.month]).agg({'highest_wbt_diff_above_avg': 'sum', 'wbt_date': 'first'})
# temp_df_1.rename(columns={'wbt_date':'month', 'lowest_wbt_diff_below_avg':'low_wbt_diff_below_avg_days'}, inplace=True)
# temp_df_2.rename(columns={'wbt_date':'month', 'highest_wbt_diff_above_avg':'high_wbt_diff_above_avg_days'}, inplace=True)

# temp_df_3 = wbt.groupby([wbt['wbt_date'].dt.year, wbt['wbt_date'].dt.month]).agg({'wet_bulb_temperature': 'mean', 'wbt_date': 'first'})
# temp_df_3.rename(columns={'wbt_date':'month', 'wet_bulb_temperature':'avg_wbt'}, inplace=True)

# %%
# change column 'month' to datetime and merge with all prepared df
rain_df = rain_days.merge(rain_amount).merge(humid).merge(sunshine_hours).merge(surface_temp)
rain_df['month'] = pd.to_datetime(rain_df['month'])
# rain_df = rain_df.merge(temp_df_1).merge(temp_df_2).merge(temp_df_3)
# rain_df['surface_wbt_diff'] = rain_df['temp_mean_daily_min'] - rain_df['avg_wbt']
# del temp_df_1
# del temp_df_2
# del temp_df_3

# %%
# Display merged data
rain_df.head()
# Out:
#        month  no_of_rainy_days  total_rainfall  mean_rh  mean_sunshine_hrs  \
# 0 1982-01-01                10           107.1     81.2                5.6
# 1 1982-02-01                 5            27.8     79.5                7.6
# 2 1982-03-01                11           160.8     82.3                5.1
# 3 1982-04-01                14           157.0     85.9                4.7
# 4 1982-05-01                10           102.2     83.2                5.8
#
#    mean_temp
# 0       25.9
# 1       27.1
# 2       27.2
# 3       27.0
# 4       28.0

# %%
# rename column
rain_df.rename(columns={
    'no_of_rainy_days':'rain_days',
    'total_rainfall':'rain_amount',
    'mean_rh':'humidity',
    'mean_sunshine_hrs':'sun_hrs'
}, inplace=True)
rain_df.head()
# Out:
#        month  rain_days  rain_amount  humidity  sun_hrs  mean_temp
# 0 1982-01-01         10        107.1      81.2      5.6       25.9
# 1 1982-02-01          5         27.8      79.5      7.6       27.1
# 2 1982-03-01         11        160.8      82.3      5.1       27.2
# 3 1982-04-01         14        157.0      85.9      4.7       27.0
# 4 1982-05-01         10        102.2      83.2      5.8       28.0

# %%
# Check missing value and datatype
rain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        488 non-null    datetime64[ns]
#  1   rain_days    488 non-null    int64
#  2   rain_amount  488 non-null    float64
#  3   humidity     488 non-null    float64
#  4   sun_hrs      488 non-null    float64
#  5   mean_temp    488 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 23.0 KB

# %%
# create another df without outlier for further use
rain_df_no_outlier = rain_df.copy()
for feature in rain_df_no_outlier.iloc[:,1:7]:
    q1 = np.percentile(rain_df_no_outlier[feature], 25)
    q3 = np.percentile(rain_df_no_outlier[feature], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    rain_df_no_outlier[feature] = rain_df_no_outlier[feature].apply(lambda x: x if lower_bound <= x <= upper_bound else np.nan)

rain_df_no_outlier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        488 non-null    datetime64[ns]
#  1   rain_days    488 non-null    int64
#  2   rain_amount  474 non-null    float64
#  3   humidity     484 non-null    float64
#  4   sun_hrs      484 non-null    float64
#  5   mean_temp    488 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 23.0 KB

# %%
# save to csv
rain_df.to_csv('../data/rain_df.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %%
# Display merged data for creating data dict
rain_df.head()
# Out:
#        month  rain_days  rain_amount  humidity  sun_hrs  mean_temp
# 0 1982-01-01         10        107.1      81.2      5.6       25.9
# 1 1982-02-01          5         27.8      79.5      7.6       27.1
# 2 1982-03-01         11        160.8      82.3      5.1       27.2
# 3 1982-04-01         14        157.0      85.9      4.7       27.0
# 4 1982-05-01         10        102.2      83.2      5.8       28.0

# %%
# Display merged data types
rain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        488 non-null    datetime64[ns]
#  1   rain_days    488 non-null    int64
#  2   rain_amount  488 non-null    float64
#  3   humidity     488 non-null    float64
#  4   sun_hrs      488 non-null    float64
#  5   mean_temp    488 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 23.0 KB

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |month|datetime|rain_df|Month (YYYY-MM-01)|
# |rain_days|integer|rain_df|Monthly number of rainy days|
# |rain_amount|float|rain_df|Amount of monthly rainfall, in mm(millimeters)|
# |humidity|float|rain_df|Monthly average relative humidity|
# |sun_hrs|float|rain_df|Monthly average sunshine hours|
# |mean_temp|float|rain_df|Monthly average surface temperature (degree celsius)|
# |date|datetime|Flight Price|Month (YYYY-MM-01)|
# |price|datetime|Flight Price|Average flight price from Bangkok to Singapore (round-trip, 4 days) in baht|
#
# ~~|low_wbt_diff_below_avg_days|float|rain_df|Number of days in a month that have the lowest hourly difference of web bulb temperature lower than its average|
# |high_wbt_diff_above_avg_days|float|rain_df|Number of days in a month that have the highest hourly difference of web bulb temperature higher than its average|~~

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Summary stats
rain_df.describe()
# Out:
#                                month   rain_days  rain_amount    humidity  \
# count                            488  488.000000   488.000000  488.000000
# mean   2002-04-16 16:55:04.918032768   14.061475   177.163730   82.247541
# min              1982-01-01 00:00:00    1.000000     0.200000   72.000000
# 25%              1992-02-22 18:00:00   11.000000    93.850000   80.000000
# 50%              2002-04-16 00:00:00   14.000000   159.450000   82.650000
# 75%              2012-06-08 12:00:00   18.000000   238.075000   84.700000
# max              2022-08-01 00:00:00   27.000000   765.900000   90.700000
# std                              NaN    4.947394   113.916029    3.413940
#
#           sun_hrs   mean_temp
# count  488.000000  488.000000
# mean     5.688320   27.678893
# min      2.700000   25.400000
# 25%      4.800000   27.100000
# 50%      5.700000   27.700000
# 75%      6.500000   28.300000
# max      9.300000   29.500000
# std      1.205705    0.802195

# %%
# Find Std using written function
std_values = {column: std_calc(rain_df[column]) for column in rain_df if column != 'month'}
std_values
# Out:
# {'rain_days': 4.9423221913224085,
#  'rain_amount': 113.79925170470058,
#  'humidity': 3.410439929190284,
#  'sun_hrs': 1.2044686452879798,
#  'mean_temp': 0.8013725449868123}

# %%
# Highest/lowest total rainfall month of 1990, 2000, 2010, 2020
for year in [1990, 2000, 2010, 2020]:
    print(year, '\nHighest', rain_df.loc[rain_df['month'].dt.year == year, ['month', 'rain_amount']].max(), '\n')
    print('Lowest', rain_df.loc[rain_df['month'].dt.year == year, ['month', 'rain_amount']].min(), '\n')
# Out:
# 1990
# Highest month          1990-12-01 00:00:00
# rain_amount                  204.5
# dtype: object
#
# Lowest month          1990-01-01 00:00:00
# rain_amount                   24.1
# dtype: object
#
# 2000
# Highest month          2000-12-01 00:00:00
# rain_amount                  385.7
# dtype: object
#
# Lowest month          2000-01-01 00:00:00
# rain_amount                   81.1
# dtype: object
#
# 2010
# Highest month          2010-12-01 00:00:00
# rain_amount                  298.5
# dtype: object
#
# Lowest month          2010-01-01 00:00:00
# rain_amount                    6.3
# dtype: object
#
# 2020
# Highest month          2020-12-01 00:00:00
# rain_amount                  255.6
# dtype: object
#
# Lowest month          2020-01-01 00:00:00
# rain_amount                   65.0
# dtype: object

# %% [markdown]
# > **Finding:**
# >
# > December has the highest rain amount for all of specific years.
# >
# > January has the lowest rain amount for all of specific years.

# %%
# Highest and lowest total rainfall per year
# print(rain_df.groupby(rain_df['month'].dt.year)['total_rainfall'].sum().idxmax(), rain_df.groupby(rain_df['month'].dt.year)['total_rainfall'].sum().max())
# print(rain_df.groupby(rain_df['month'].dt.year)['total_rainfall'].sum().idxmin(), rain_df.groupby(rain_df['month'].dt.year)['total_rainfall'].sum().min())
rain_df.groupby(rain_df['month'].dt.year)['rain_amount'].sum().sort_values(ascending=False)
# Out:
# month
# 2007    2886.2
# 2021    2809.6
# 2001    2783.1
# 2006    2753.2
# 2013    2748.4
# 1984    2686.7
# 1998    2623.1
# 1988    2598.6
# 1986    2536.1
# 2011    2524.2
# 1989    2463.2
# 1996    2418.0
# 2003    2391.2
# 2000    2370.5
# 1995    2332.6
# 2008    2325.1
# 1992    2260.8
# 1993    2168.7
# 2012    2159.9
# 2004    2136.4
# 1999    2134.0
# 1987    2102.8
# 2010    2075.1
# 2017    2045.6
# 1983    1993.7
# 2016    1955.7
# 1994    1941.8
# 2005    1930.7
# 2009    1920.9
# 2020    1886.6
# 1991    1877.0
# 2002    1748.9
# 2018    1708.2
# 1982    1581.7
# 2014    1538.4
# 1990    1523.8
# 1985    1483.9
# 2019    1367.5
# 2022    1278.0
# 2015    1267.1
# 1997    1118.9
# Name: rain_amount, dtype: float64

# %% [markdown]
# > **Finding:**
# >
# > Year 2007 has the highest amount of total rainfall and the lowest is 1997.

# %%
# Month with highest/lowest rainy days of 1990, 2000, 2010, 2020
for year in [1990, 2000, 2010, 2020]:
    print(year, '\nHighest', rain_df.loc[rain_df['month'].dt.year == year, ['month', 'rain_days']].max(), '\n')
    print('Lowest', rain_df.loc[rain_df['month'].dt.year == year, ['month', 'rain_days']].min(), '\n')
# Out:
# 1990
# Highest month        1990-12-01 00:00:00
# rain_days                     17
# dtype: object
#
# Lowest month        1990-01-01 00:00:00
# rain_days                      4
# dtype: object
#
# 2000
# Highest month        2000-12-01 00:00:00
# rain_days                     21
# dtype: object
#
# Lowest month        2000-01-01 00:00:00
# rain_days                     10
# dtype: object
#
# 2010
# Highest month        2010-12-01 00:00:00
# rain_days                     21
# dtype: object
#
# Lowest month        2010-01-01 00:00:00
# rain_days                      4
# dtype: object
#
# 2020
# Highest month        2020-12-01 00:00:00
# rain_days                     22
# dtype: object
#
# Lowest month        2020-01-01 00:00:00
# rain_days                      6
# dtype: object

# %% [markdown]
# > **Finding:**
# >
# > December has the highest no. of rainy days for all of specific years.
# >
# >January has the lowest no. of rainy days for all of specific years.

# %%
# Highest and lowest no. of rainy days per year
rain_df.groupby(rain_df['month'].dt.year)['rain_days'].sum().sort_values(ascending=False)
# Out:
# month
# 2013    206
# 2017    204
# 2007    195
# 1984    191
# 2012    191
# 2018    188
# 2011    188
# 2000    188
# 2003    186
# 2001    184
# 2008    182
# 2021    182
# 1985    181
# 1995    179
# 2016    179
# 2010    178
# 2020    178
# 1999    177
# 1998    177
# 2005    175
# 1986    174
# 2006    174
# 1989    173
# 1988    173
# 1996    170
# 2009    166
# 1993    163
# 1992    163
# 1994    160
# 2014    152
# 1987    151
# 2004    147
# 1991    146
# 1983    145
# 1990    142
# 2002    139
# 1982    130
# 2015    125
# 2022    124
# 2019    120
# 1997    116
# Name: rain_days, dtype: int64

# %% [markdown]
# > **Finding:**
# >
# > Year 2013 has the highest no. of rainy days and the lowest is 1997.

# %%
# Check outlier from earlier dataframe
print(rain_df.info(), '\n')
print(rain_df_no_outlier.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        488 non-null    datetime64[ns]
#  1   rain_days    488 non-null    int64
#  2   rain_amount  488 non-null    float64
#  3   humidity     488 non-null    float64
#  4   sun_hrs      488 non-null    float64
#  5   mean_temp    488 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 23.0 KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        488 non-null    datetime64[ns]
#  1   rain_days    488 non-null    int64
#  2   rain_amount  474 non-null    float64
#  3   humidity     484 non-null    float64
#  4   sun_hrs      484 non-null    float64
# ...

# %% [markdown]
# > **Finding:**
# >
# > There are some outliers in rain_amount, humidity and sun_hrs in some months.

# %%
# Check average rain amount in each month over the past years
rain_df.groupby(rain_df['month'].dt.month)['rain_amount'].mean()
# Out:
# month
# 1     234.295122
# 2     103.919512
# 3     160.904878
# 4     158.480488
# 5     166.221951
# 6     135.180488
# 7     147.387805
# 8     149.424390
# 9     147.287500
# 10    159.677500
# 11    256.170000
# 12    311.052500
# Name: rain_amount, dtype: float64

# %% [markdown]
# > **Finding:**
# >
# > In average, December have the highest total amount of rain over the past years and February has the lowest.

# %%
# Check average rainy days in each month over the past years
rain_df.groupby(rain_df['month'].dt.month)['rain_days'].mean()
# Out:
# month
# 1     13.365854
# 2      8.292683
# 3     12.487805
# 4     14.439024
# 5     13.926829
# 6     13.195122
# 7     13.512195
# 8     13.902439
# 9     13.225000
# 10    14.950000
# 11    19.025000
# 12    18.650000
# Name: rain_days, dtype: float64

# %% [markdown]
# > **Finding:**
# >
# > In average, November and December have the highest number of rainy days over the past years and February has the lowest.

# %%
# Find average of rainy days in regular months (Jan and Mar-Oct), Feb and Nov/Dec
print('Rugular month average rainy days:', round(rain_df.loc[~(rain_df['month'].dt.month.isin([2, 11, 12])), 'rain_days'].mean()))
print('Feb:', round(rain_df.loc[(rain_df['month'].dt.month.isin([2])), 'rain_days'].mean()))
print('Nov, Dec:', round(rain_df.loc[(rain_df['month'].dt.month.isin([11, 12])), 'rain_days'].mean()))
# Out:
# Rugular month average rainy days: 14
# Feb: 8
# Nov, Dec: 19

# %%
# For regular months
rate_of_rain = 14

rain_dist = stats.poisson(rate_of_rain)
possible_num_of_rain_days = list(range(31))

# plt.bar(possible_num_of_rain_days, rain_dist.pmf(possible_num_of_rain_days))
# plt.xlabel('Number of rainy days, average of 14 rainy days in regular month')
# plt.ylabel('Probability');

# %%
# Chance of encounter more than 5 days of rain
1-rain_dist.cdf(5) - (1-rain_dist.cdf(31))
# Out:
# 0.9944422854492164

# %%
# For November/December
rate_of_rain = 19

rain_dist = stats.poisson(rate_of_rain)
possible_num_of_rain_days = list(range(31))

# plt.bar(possible_num_of_rain_days, rain_dist.pmf(possible_num_of_rain_days))
# plt.xlabel('Number of rainy days, given average of 19.025 rainy days in November')
# plt.ylabel('Probability');

# %%
# Chance of encounter more than 9 days of rain
1-rain_dist.cdf(8) - (1-rain_dist.cdf(31))
# Out:
# 0.992128428625132

# %%
# History maximum
rain_df.loc[(rain_df['month'].dt.month == 11) | (rain_df['month'].dt.month == 12)].groupby(rain_df['month'].dt.month)['rain_days'].max()
# Out:
# month
# 11    27
# 12    24
# Name: rain_days, dtype: int64

# %%
# For February
rate_of_rain = 8

rain_dist = stats.poisson(rate_of_rain)
possible_num_of_rain_days = list(range(31))

# plt.bar(possible_num_of_rain_days, rain_dist.pmf(possible_num_of_rain_days))
# plt.xlabel('Number of rainy days, given average of 19.025 rainy days in November')
# plt.ylabel('Probability');

# %%
# Chance of encounter 15 days of rain at maximum
rain_dist.cdf(15)
# Out:
# 0.9917689890131551

# %% [markdown]
# > **Finding:**
# >
# > There is 99% chance that it will rain at least 9 days in November, December and at least 5 days in January / March - October.
# >
# > On the other hand, in February, there is also 99% chance that you will not encounter more than 15 days of rain.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %%
# Visualize boxplot for outlier checking
plt.figure(figsize=(25,8))
plt.subplot(1, 5, 1)
sns.boxplot(rain_df['rain_days'], width=0.2)

plt.subplot(1, 5, 2)
sns.boxplot(rain_df['rain_amount'], width=0.2)

plt.subplot(1, 5, 3)
sns.boxplot(rain_df['humidity'], width=0.2)

plt.subplot(1, 5, 4)
sns.boxplot(rain_df['sun_hrs'], width=0.2)

plt.subplot(1, 5, 5)
sns.boxplot(rain_df['mean_temp'], width=0.2);

# %%
# Pairplot for relationship finding and distribution
sns.pairplot(rain_df);

# %%
# Plot correlation heatmap to find relationship
plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(rain_df.corr(numeric_only=True)), k=1)
sns.heatmap(rain_df.corr(numeric_only=True), vmax=1, vmin=-1, annot=True, cmap='coolwarm', fmt='.2f', mask=mask).set_title('Correlations heatmap of each features pair').set_fontsize(15);

# %% [markdown]
# > **Finding:**
# >
# > Rain amount, number of rainy days and the average humidity relationship seems to be in the same direction as they have positive correlation,
# >
# > while average sunshine hours goes in the opposite direction.

# %%
# Plot comparison of average rain and sunshine hours, highlight some of interesting information
temp_df = rain_df[['month', 'rain_days', 'rain_amount', 'sun_hrs', 'humidity']].groupby(rain_df['month'].dt.month)[['rain_days', 'rain_amount', 'sun_hrs', 'humidity']].mean().sort_values('rain_days')
sns.set_theme()
plt.figure(figsize=(10,15))

palette_1 = []
palette_2 = []
for i in range(1,13):
    if i in [2, 12]:
        palette_1.append((0.7686274509803922, 0.3058823529411765, 0.3215686274509804))
        palette_2.append((0.7686274509803922, 0.3058823529411765, 0.3215686274509804))
    elif i == 11:
        palette_1.append((0.7686274509803922, 0.3058823529411765, 0.3215686274509804))
        palette_2.append((0.2980392156862745, 0.4470588235294118, 0.6901960784313725))
    else:
        palette_1.append((0.2980392156862745, 0.4470588235294118, 0.6901960784313725))
        palette_2.append((0.2980392156862745, 0.4470588235294118, 0.6901960784313725))

plt.subplot(5, 1, 1)
plt.title('Comparison of Average Rainfall and Sunshine Hrs.').set_fontsize(15)
ax1 = sns.barplot(x=temp_df.index, y=round(temp_df['rain_days']), palette=palette_1)
# ax1.bar_label(ax1.containers[0], fmt='%.0f')
plt.ylabel('# Rain days')
plt.xlabel(None)

plt.subplot(5, 1, 2)
ax2 = sns.barplot(x=temp_df.index, y=temp_df['rain_amount'], palette=palette_2)
# ax2.bar_label(ax2.containers[0], fmt='%.2f')
plt.ylabel('Total Rainfall (mm)')
plt.xlabel(None)

plt.subplot(5, 1, 3)
ax3 = sns.barplot(x=temp_df.index, y=temp_df['sun_hrs'], palette=palette_1)
# ax3.bar_label(ax3.containers[0], fmt='%.2f')
plt.axhline(y=6.5, color='black', linestyle='--')
plt.axhline(y=4.5, color='black', linestyle='--')
plt.ylabel('Sunshine Hours')
plt.xlabel('Month')
plt.yticks([1, 2, 3, 4, 5, 6, 7]);

# plt.subplot(5, 1, 4)
# plt.bar(x=temp_df.index, height=temp_df['mean_rh'])
# plt.xlabel('Humidity')

# plt.subplot(5, 1, 5)
# plt.bar(x=temp_df.index, height=temp_df['temp_mean_daily_min'])
# plt.xlabel('Temperature')
# Out:
# C:\Users\icyge\AppData\Local\Temp\ipykernel_17148\1386429573.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(x=temp_df.index, y=round(temp_df['rain_days']), palette=palette_1)
# C:\Users\icyge\AppData\Local\Temp\ipykernel_17148\1386429573.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.barplot(x=temp_df.index, y=temp_df['rain_amount'], palette=palette_2)
# C:\Users\icyge\AppData\Local\Temp\ipykernel_17148\1386429573.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# > **Finding:**
# >
# > For rainy days are highest, while the best one is February.
# >
# > When looking at the average sunshine hours in the specific month above, when it is higher than 6.5 or lower than 4.5 hrs. the number of rainy days goes up or down significantly.

# %%
# Check Seaborn color palette
print(sns.color_palette())
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725), (0.8666666666666667, 0.5176470588235295, 0.3215686274509804), (0.3333333333333333, 0.6588235294117647, 0.40784313725490196), (0.7686274509803922, 0.3058823529411765, 0.3215686274509804), (0.5058823529411764, 0.4470588235294118, 0.7019607843137254), (0.5764705882352941, 0.47058823529411764, 0.3764705882352941), (0.8549019607843137, 0.5450980392156862, 0.7647058823529411), (0.5490196078431373, 0.5490196078431373, 0.5490196078431373), (0.8, 0.7254901960784313, 0.4549019607843137), (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
# Plot number of rainy days with crowded highlight
palette_3 = []
for i in range(1,13):
    if i in [2, 5, 6, 12]:
        palette_3.append((0.8666666666666667, 0.5176470588235295, 0.3215686274509804))
    elif i in [7, 8, 9, 10]:
        palette_3.append((0.39215686274509803, 0.7098039215686275, 0.803921568627451))
    else:
        palette_3.append((0.2980392156862745, 0.4470588235294118, 0.6901960784313725))

plt.figure(figsize=(10,5))
plt.title('Average number of rainy day (crowded month in orange and light blue)').set_fontsize(15)
ax1 = sns.barplot(x=temp_df.index, y=round(temp_df['rain_days']), palette=palette_3)
# ax1.plot(1, 9, "*", markersize=10, color="r") # Chinese new year
# ax1.plot(4, 15, "*", markersize=10, color="r") # Start of school holidays
# ax1.plot(5, 14, "*", markersize=10, color="r") # School holidays continued + great singapore sale
# ax1.plot(6, 15, "*", markersize=10, color="r") # Great singapore sale
# ax1.plot(11, 20, "*", markersize=10, color="r") # Festive time, Xmas + New year
plt.ylabel('# Rain days')
plt.xlabel(None)
# Out:
# C:\Users\icyge\AppData\Local\Temp\ipykernel_17148\4249082656.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(x=temp_df.index, y=round(temp_df['rain_days']), palette=palette_3)
# Text(0.5, 0, '')

# %%
# plt.hist(rain_df.loc[rain_df['month'].dt.month == 11]['no_of_rainy_days'])
# sns.histplot(rain_df.loc[rain_df['month'].dt.month == 11]['rain_days'], bins=10)
# sns.set_theme()
# plt.title('Histogram of number of rainy days in November (distributed over the past years)')
# plt.xlabel('# days')
# plt.ylabel('Frequency');

# %%
# plt.hist(rain_df.loc[rain_df['month'].dt.month == 11]['no_of_rainy_days'])
# sns.histplot(rain_df.loc[rain_df['month'].dt.month == 12]['rain_days'], bins=10)
# sns.set_theme()
# plt.title('Histogram of number of rainy days in December (distributed over the past years)')
# plt.xlabel('# days')
# plt.ylabel('Frequency');

# %%
# Plot average surface temperature overlayed by rain days
plt.figure(figsize=(8,5))
plt.plot(rain_df.groupby(rain_df['month'].dt.month)['mean_temp'].mean())
plt.title('Average surface temperature by month').set_fontsize(15)
plt.xticks(list(range(1, 13)))
plt.xlabel('Month')
plt.ylabel('Degree Celsius');

ax2 = plt.gca().twinx()
ax2.bar(temp_df.index, temp_df['rain_days'], width=0.4, color='gray', alpha=0.3, label='Bar Plot')
ax2.set_yticks([]);

# %%
# Plot relative humidity by month
plt.figure(figsize=(8,5))
plt.plot(rain_df.groupby(rain_df['month'].dt.month)['humidity'].mean())
plt.title('Average relative humidity by month').set_fontsize(15)
plt.xticks(list(range(1, 13)))
plt.xlabel('Month')
plt.ylabel('Percent');

# %%
# Plot average rainy days by month, to find if there is any trends
plt.figure(figsize=(8,5))
plt.plot(rain_df.groupby(rain_df['month'].dt.year)['rain_days'].sum().sort_index())
plt.title('Total rainy days per year').set_fontsize(15)
plt.xlabel('Year')
plt.ylabel('Millimeters');

# %%
# Plot average rainy amount by month, to find if there is any trends
plt.figure(figsize=(8,5))
plt.plot(rain_df.groupby(rain_df['month'].dt.year)['rain_amount'].sum().sort_index())
plt.title('Total rain amount per year').set_fontsize(15)
plt.xlabel('Year')
plt.ylabel('Millimeters');

# %% [markdown]
# > **Finding:**
# >
# > There is no trend in the number of rainy days and the amount of rain.

# %%
# Load additional flight price data just for plotting
flight_price = pd.read_csv('../data/Flight Price.csv')
flight_price['date'] = pd.to_datetime(flight_price['date'], format='%d-%b')

# %%
# Plot average flight price overlayed by rain days
plt.figure(figsize=(8,5))
plt.plot(flight_price.groupby(flight_price['date'].dt.month)['price'].mean(), color='red')
plt.title('Average flight price by month (Bangkok to Singapore, 4 days trip)').set_fontsize(15)
plt.xticks(list(range(1, 13)))
plt.xlabel('Month')
plt.ylabel('Baht')

ax2 = plt.gca().twinx()
ax2.bar(temp_df.index, temp_df['rain_days'], width=0.4, color='gray', alpha=0.3, label='Bar Plot')
ax2.set_yticks([]);

# %%
# Plot chance of encountering each number of rainy days in November & December
# For November/December
rate_of_rain = 19

rain_dist = stats.poisson(rate_of_rain)
possible_num_of_rain_days = list(range(31))

chance = []
for i in range(8, 28):
    # Chance of encounter more than 9 days of rain
    chance.append((1-rain_dist.cdf(i) - (1-rain_dist.cdf(31)))*100)

plt.figure(figsize=(8,5))
plt.title('Chance of encountering at least x rainy days').set_fontsize(15)
plt.plot(list(range(8, 28)), chance)
plt.xlabel('Minimum number of rainy days')
plt.ylabel('Percentage')
plt.xticks(list(range(8, 28)));

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# > Considered the number of rainy days, the best month to travel to Singapore is February with relatively low temperature.
# > However, it can be crowded as Chinese new year usually falls in February, picking the period earlier of later in the month should be better.
# >
# > Avoid November and December as they are the wettest months with additional of relatively high flight price.
# > Also, in November and December, if it still haven't rain at least 9 days at the near end of the month, keep it mind that it is likely to rain every day from that point.
# >
# > <br>
# > If there is no choice but to go to Singapore in November or December, focuses more or always prepare for an indoor alternate plan so you can switch anytime.
# >
# > For the other months (January and March to October), the weather condition should likely be the same. If you don't expect to go there in the "Greate Singapore Sale" season, it's better to avoid June and July. Also in this period, the most recommended month for sightseeing and outdoor activities are March and April.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
